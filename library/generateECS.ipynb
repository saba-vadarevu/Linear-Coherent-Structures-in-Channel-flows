# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np
import scipy as sp
import h5py
from scipy.interpolate import interp1d
from scipy.linalg import sqrtm, solve_sylvester, solve_lyapunov
import matplotlib.pyplot as plt
import sys
import pseudo
import os
import glob
import miscUtil
import ops
# %matplotlib inline
#%matplotlib notebook

os.environ['DATA'] = os.environ['DATA186']
physDataDir = os.environ['DATA'] + 'phys/'
specDataDir = os.environ['DATA'] + 'spec/'
covDataDir = os.environ['DATA'] + 'cov/'
libDir = os.environ['LINLIB']
figureFolder = 'newFigures/'

# %% [markdown]
# # Recurrence plots for channel TWS
#
# ## Low-res test case

# %%
loadPath = os.environ['HOME']+'/channelflow/work/test/'
recData = np.loadtxt(loadPath+'dist.asc',comments='%')
plt.contourf(recData.T, levels=np.arange(0.,0.2,0.002), cmap='rainbow')
plt.colorbar()
plt.show()

# %%
tArr = np.arange(0,1001,10)
Nx = 32; Ny = 33; Nz = 32 
frameDir = loadPath + 'frames/'
# xy planes
xyPlanes = np.zeros((tArr.size, 3, Ny, Nx))
for ind in range(tArr.size):
    t = tArr[ind]
    fName = frameDir + 'u%d_u_xy.asc'%t
    xyPlanes[ind,0] = np.loadtxt(fName, comments='%')[:, :-1]
    fName = frameDir + 'u%d_v_xy.asc'%t
    xyPlanes[ind,1] = np.loadtxt(fName, comments='%')[:, :-1]
    fName = frameDir + 'u%d_w_xy.asc'%t
    xyPlanes[ind,2] = np.loadtxt(fName, comments='%')[:, :-1]

#xyPlanes[:,0] += (1. - yArr**2).reshape(1,Ny,1)

# %%
Lx = 0.875 * 2.* np.pi; Lz = 0.6 * 2.* np.pi
xArr = np.arange(0., Lx, Lx/Nx)
yArr = pseudo.chebdif(Ny,1)[0]

for ind in range(0,tArr.size, tArr.size//10):
    plt.figure()
    plt.contourf(xArr, yArr, xyPlanes[ind,0] , 100, cmap='afmhot' )
    plt.colorbar()
    plt.show()

# %% [markdown]
# ## High-Res case (48x35x32)

# %%
loadPath = os.environ['HOME']+'/channelflow/work/R2000/'
recData = np.loadtxt(loadPath+'dist.asc',comments='%')
plt.contourf(recData.T, levels=np.arange(0.,0.05,0.0005), cmap='rainbow')
plt.colorbar()
plt.show()

# %%
tArr = np.arange(0,1001,10)
Nx = 32; Ny = 33; Nz = 32 
frameDir = loadPath + 'frames/'
# xy planes
xyPlanes = np.zeros((tArr.size, 3, Ny, Nx))
for ind in range(tArr.size):
    t = tArr[ind]
    fName = frameDir + 'u%d_u_xy.asc'%t
    xyPlanes[ind,0] = np.loadtxt(fName, comments='%')[:, :-1]
    fName = frameDir + 'u%d_v_xy.asc'%t
    xyPlanes[ind,1] = np.loadtxt(fName, comments='%')[:, :-1]
    fName = frameDir + 'u%d_w_xy.asc'%t
    xyPlanes[ind,2] = np.loadtxt(fName, comments='%')[:, :-1]

#xyPlanes[:,0] += (1. - yArr**2).reshape(1,Ny,1)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-34-8d87fd8aafca> in <module>()
#       7     t = tArr[ind]
#       8     fName = frameDir + 'u%d_u_xy.asc'%t
# ----> 9     xyPlanes[ind,0] = np.loadtxt(fName, comments='%')[:, :-1]
#      10     fName = frameDir + 'u%d_v_xy.asc'%t
#      11     xyPlanes[ind,1] = np.loadtxt(fName, comments='%')[:, :-1]
#
# /home/svadarevu/linenv/lib/python3.5/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin)
#     858                 fh = iter(open(fname, 'U'))
#     859             else:
# --> 860                 fh = iter(open(fname))
#     861         else:
#     862             fh = iter(fname)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/svadarevu/channelflow/work/Rt90/frames/u0_u_xy.asc'

# %%
loadPath = os.environ['HOME']+'/channelflow/work/R2000/'
recData = np.loadtxt(loadPath+'dist.asc',comments='%')
plt.contourf(recData.T, levels=np.arange(0.,0.1,0.002), cmap='rainbow')
plt.colorbar()
plt.show()
